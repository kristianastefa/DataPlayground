# %% [markdown]
# ### Implementing the following recommender systems using the training set to train them, based on user ratings for books in the amazon dataset.
# 1. Non-personalized recommender
# 2. Content-based recommender based on K=50 nearest neighbors
# 3. User-user collaborative filtering
# 4. SVD

# %%
import re
import io
import time
import math
import numpy as np
import pandas as pd
from scipy import sparse
from sparselsh import LSH
from scipy.sparse import vstack
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from datetime import datetime, timedelta
from collections import defaultdict
# Load Surprise libraries
from surprise import KNNBasic
from surprise import Reader
from surprise import Dataset
from surprise import accuracy
from surprise import SVD
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split
from surprise import accuracy

# %% [markdown]
# ### Load and Pre-Process Data

# %% [markdown]
# #### Amazon Books

# %%
df_b = pd.read_csv('../data/amazon/books_meta.csv')
ratings_train_df = pd.read_csv('../data/amazon/books_ratings_training.csv')
ratings_test_df = pd.read_csv('../data/amazon/books_ratings_test.csv')

# %%
df_b.head()
# Out:
#    item_id                                              title  price  \
# 0        1                                    Parker & Knight    0.0
# 1        2                     Need You Now - A Story of Hope  13.97
# 2        3                                           Jealousy    0.0
# 3        4  Meat Eater: Adventures from the Life of an Ame...   49.0
# 4        5  The Last Valley: Dien Bien Phu and the French ...  37.43
#
#                                           categories
# 0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 1                                                 []
# 2  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 3  ['Books', 'Cookbooks, Food & Wine', 'Cooking b...
# 4                   ['Books', 'History', 'Military']

# %%
duplicates = df_b.duplicated().sum()
print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 0

# %%
missing_values = df_b.isnull().sum()
print(missing_values)
# Out:
# item_id          0
# title            0
# price         7647
# categories       0
# dtype: int64

# %%
# Replace various representations of empty values with None
df_b.replace(['', ' ', '-', np.nan], None, inplace=True)
df_b.head()
# Out:
#    item_id                                              title  price  \
# 0        1                                    Parker & Knight    0.0
# 1        2                     Need You Now - A Story of Hope  13.97
# 2        3                                           Jealousy    0.0
# 3        4  Meat Eater: Adventures from the Life of an Ame...   49.0
# 4        5  The Last Valley: Dien Bien Phu and the French ...  37.43
#
#                                           categories
# 0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 1                                                 []
# 2  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 3  ['Books', 'Cookbooks, Food & Wine', 'Cooking b...
# 4                   ['Books', 'History', 'Military']

# %%
df_b = df_b[df_b['categories']!='[]']

# %%
# df_b[df_b['categories']=='[]']

# %%
# Function to split categories, remove excessive spaces, and expand into separate rows
def split_and_expand_categories(row):
    categories = eval(row['categories'])
    expanded_categories = []
    for category in categories:
        sub_categories = [x.strip() for x in category.split(',')]
        clean_sub_categories = [re.sub(r'\s+', ' ', sub_cat).strip() for sub_cat in sub_categories]        
        expanded_categories.extend(clean_sub_categories)
    return pd.Series(expanded_categories)

expanded_categories_df = df_b.apply(split_and_expand_categories, axis=1).stack().reset_index(level=1, drop=True).rename('category')
expanded_df = df_b.drop('categories', axis=1).join(expanded_categories_df).reset_index(drop=True)

expanded_df
# Out:
#         item_id                                              title  price  \
# 0             1                                    Parker & Knight    0.0
# 1             1                                    Parker & Knight    0.0
# 2             1                                    Parker & Knight    0.0
# 3             1                                    Parker & Knight    0.0
# 4             3                                           Jealousy    0.0
# ...         ...                                                ...    ...
# 185789    56947  The Secret Teachings of All Ages (Reader's Edi...  19.49
# 185790    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
# 185791    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
# 185792    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
# 185793    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
#
#                     category
# 0                      Books
# 1                    Mystery
# 2        Thriller & Suspense
# 3       Thrillers & Suspense
# 4                      Books
# ...                      ...
# 185789  Literature & Fiction
# 185790                 Books
# 185791               Mystery
# 185792   Thriller & Suspense
# 185793               Mystery
#
# [185794 rows x 4 columns]

# %%
expanded_df = expanded_df.drop_duplicates(subset=['item_id', 'category'])
expanded_df
# Out:
#         item_id                                              title  price  \
# 0             1                                    Parker & Knight    0.0
# 1             1                                    Parker & Knight    0.0
# 2             1                                    Parker & Knight    0.0
# 3             1                                    Parker & Knight    0.0
# 4             3                                           Jealousy    0.0
# ...         ...                                                ...    ...
# 185788    56947  The Secret Teachings of All Ages (Reader's Edi...  19.49
# 185789    56947  The Secret Teachings of All Ages (Reader's Edi...  19.49
# 185790    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
# 185791    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
# 185792    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
#
#                        category
# 0                         Books
# 1                       Mystery
# 2           Thriller & Suspense
# 3          Thrillers & Suspense
# 4                         Books
# ...                         ...
# 185788  Religion & Spirituality
# 185789     Literature & Fiction
# 185790                    Books
# 185791                  Mystery
# 185792      Thriller & Suspense
#
# [183267 rows x 4 columns]

# %%
# For Checking
# tryi = expanded_df[expanded_df['category']=='']
# tryi
# missing_values = df_b.isnull().sum()
# print(missing_values)
# count_comma_in_category = expanded_categories_df['category'].str.contains(',').sum()
# count_comma_in_category

# %%
expanded_categories_df = expanded_df

# %%
df = df_b.drop(['categories', 'price'], axis=1)
df
# Out:
#        item_id                                              title
# 0            1                                    Parker & Knight
# 2            3                                           Jealousy
# 3            4  Meat Eater: Adventures from the Life of an Ame...
# 4            5  The Last Valley: Dien Bien Phu and the French ...
# 5            6        Woodstock: Three Days That Rocked the World
# ...        ...                                                ...
# 56943    56944  How Much for Just the Planet? (Star Trek, Book...
# 56944    56945  M Is For Mitten: A Michigan Alphabet (Discover...
# 56945    56946  Manga for the Beginner Shoujo: Everything You ...
# 56946    56947  The Secret Teachings of All Ages (Reader's Edi...
# 56947    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...
#
# [55952 rows x 2 columns]

# %%
# Merge expanded categories with ratings_train_df
merged_train_df = pd.merge(ratings_train_df, expanded_categories_df, on='item_id')

# Merge expanded categories with ratings_test_df
merged_test_df = pd.merge(ratings_test_df, expanded_categories_df, on='item_id')

# %%
merged_train_df.columns
# Out:
# Index(['user_id', 'item_id', 'rating', 'timestamp', 'title', 'price',
#        'category'],
#       dtype='object')

# %%
merged_train_tags = merged_train_df[['user_id', 'item_id', 'title', 'category', 'timestamp']]
merged_train_tags
# Out:
#         user_id  item_id                                          title  \
# 0          3361    53296            Crescent Dawn (Dirk Pitt Adventure)
# 1          3361    53296            Crescent Dawn (Dirk Pitt Adventure)
# 2          3361    53296            Crescent Dawn (Dirk Pitt Adventure)
# 3          4471     1424  Cars (Disney/Pixar Cars) (Little Golden Book)
# 4          4471     1424  Cars (Disney/Pixar Cars) (Little Golden Book)
# ...         ...      ...                                            ...
# 262164     6954    53231                            Pride and Prejudice
# 262165     6954    53231                            Pride and Prejudice
# 262166     6322    47262   The Red Sword (The Red Sword Trilogy Book 1)
# 262167     6322    47262   The Red Sword (The Red Sword Trilogy Book 1)
# 262168     6322    47262   The Red Sword (The Red Sword Trilogy Book 1)
#
#                     category      timestamp
# 0                      Books  1543536132144
# 1       Literature & Fiction  1543536132144
# 2         Action & Adventure  1543536132144
# 3                      Books  1543536168823
# 4           Children's Books  1543536168823
# ...                      ...            ...
# 262164  Literature & Fiction  1555050587832
# 262165              Classics  1555050587832
# 262166                 Books  1555050710933
# 262167  Literature & Fiction  1555050710933
# 262168         Genre Fiction  1555050710933
#
# [262169 rows x 5 columns]

# %%
# Merge expanded categories with ratings_train_df
merged_train_df_new = pd.merge(ratings_train_df, df, on='item_id')

# Merge expanded categories with ratings_test_df
merged_test_df_new = pd.merge(ratings_test_df, df, on='item_id')
df_rating_test = merged_test_df_new[['user_id', 'item_id', 'title', 'rating', 'timestamp']]
df_ratings = merged_train_df_new[['user_id', 'item_id', 'title', 'rating', 'timestamp']]
df_ratings
# Out:
#        user_id  item_id                                              title  \
# 0         3361    53296                Crescent Dawn (Dirk Pitt Adventure)
# 1         4471     1424      Cars (Disney/Pixar Cars) (Little Golden Book)
# 2          342    50326  Love Coloring Book: An Adult Coloring Book wit...
# 3        10576     1953  Magic Tree House Boxed Set, Books 1-4: Dinosau...
# 4         3658     1953  Magic Tree House Boxed Set, Books 1-4: Dinosau...
# ...        ...      ...                                                ...
# 79085     8464    40568  Eternal Flame: A WWII-1980s Time Travel Love S...
# 79086     3840    56077  Moskva: 'The new Le Carre' BBC Radio 2 The Sar...
# 79087     6841    26078  Space Activity Book for Kids Ages 4-8: A Fun K...
# 79088     6954    53231                                Pride and Prejudice
# 79089     6322    47262       The Red Sword (The Red Sword Trilogy Book 1)
#
#        rating      timestamp
# 0         5.0  1543536132144
# 1         5.0  1543536168823
# 2         5.0  1543536419204
# 3         5.0  1543536938535
# 4         5.0  1546568460586
# ...       ...            ...
# 79085     4.0  1555050231806
# 79086     4.0  1555050392664
# 79087     5.0  1555050413806
# 79088     5.0  1555050587832
# 79089     5.0  1555050710933
#
# [79090 rows x 5 columns]

# %%
df_ratings_sorted = df_ratings.sort_values(by='timestamp', axis=0, ascending=False)
df_ratings_sorted
# Out:
#        user_id  item_id                                              title  \
# 79089     6322    47262       The Red Sword (The Red Sword Trilogy Book 1)
# 79088     6954    53231                                Pride and Prejudice
# 79087     6841    26078  Space Activity Book for Kids Ages 4-8: A Fun K...
# 79086     3840    56077  Moskva: 'The new Le Carre' BBC Radio 2 The Sar...
# 79085     8464    40568  Eternal Flame: A WWII-1980s Time Travel Love S...
# ...        ...      ...                                                ...
# 12        7282    51145             Geddy Lee's Big Beautiful Book of Bass
# 3        10576     1953  Magic Tree House Boxed Set, Books 1-4: Dinosau...
# 2          342    50326  Love Coloring Book: An Adult Coloring Book wit...
# 1         4471     1424      Cars (Disney/Pixar Cars) (Little Golden Book)
# 0         3361    53296                Crescent Dawn (Dirk Pitt Adventure)
#
#        rating      timestamp
# 79089     5.0  1555050710933
# 79088     5.0  1555050587832
# 79087     5.0  1555050413806
# 79086     4.0  1555050392664
# 79085     4.0  1555050231806
# ...       ...            ...
# 12        5.0  1543537322164
# 3         5.0  1543536938535
# 2         5.0  1543536419204
# 1         5.0  1543536168823
# 0         5.0  1543536132144
#
# [79090 rows x 5 columns]

# %%
# Checking
# un = df_ratings_sorted['user_id'].unique()
# uni = len(un)
# uni

# %%
# Convert the 'timestamp' column from Unix timestamps to datetime
df_ratings_sorted['timestamp'] = pd.to_datetime(df_ratings_sorted['timestamp'], unit='ms')
most_recent_timestamp = df_ratings_sorted['timestamp'].max()
cutoff_date = most_recent_timestamp - timedelta(days=30)
recent_ratings_df = df_ratings_sorted[df_ratings_sorted['timestamp'] > cutoff_date]

# %%
recent_ratings_df
# Out:
#        user_id  item_id                                              title  \
# 79089     6322    47262       The Red Sword (The Red Sword Trilogy Book 1)
# 79088     6954    53231                                Pride and Prejudice
# 79087     6841    26078  Space Activity Book for Kids Ages 4-8: A Fun K...
# 79086     3840    56077  Moskva: 'The new Le Carre' BBC Radio 2 The Sar...
# 79085     8464    40568  Eternal Flame: A WWII-1980s Time Travel Love S...
# ...        ...      ...                                                ...
# 58190    10801    42826        The Shy Little Kitten (Little Golden Books)
# 71038     5746    24688                  Dutchman and The Slave: Two Plays
# 28948     1285    28288                                       If She Wakes
# 20212     4917    43094           The Nursery (The Bayou Hauntings Book 3)
# 49238     6737    53481  Dr. Seuss's You Are Kind: Featuring Horton the...
#
#        rating               timestamp
# 79089     5.0 2019-04-12 06:31:50.933
# 79088     5.0 2019-04-12 06:29:47.832
# 79087     5.0 2019-04-12 06:26:53.806
# 79086     4.0 2019-04-12 06:26:32.664
# 79085     4.0 2019-04-12 06:23:51.806
# ...       ...                     ...
# 58190     5.0 2019-03-13 07:03:56.295
# 71038     1.0 2019-03-13 07:03:09.407
# 28948     4.0 2019-03-13 07:01:20.809
# 20212     4.0 2019-03-13 06:43:04.751
# 49238     5.0 2019-03-13 06:33:40.751
#
# [17196 rows x 5 columns]

# %% [markdown]
# ### Non personalized ranking (Damped Mean)

# %%
#USING DAMPED MEAN APPROACH
df_recent_ratings = pd.merge(recent_ratings_df, expanded_categories_df, on=['item_id', 'title'])

avg_ratings = df_recent_ratings.groupby('item_id')['rating'].mean()
num_ratings = df_recent_ratings.groupby('item_id')['rating'].count()

damping_factor = 10
damped_means = (avg_ratings * num_ratings + 2.5 * damping_factor) / (num_ratings + damping_factor)

top_books = damped_means.sort_values(ascending=False).head(20)

top_books_list = []
for item_id in top_books.index:
    book_title = df_recent_ratings.loc[df_recent_ratings['item_id'] == item_id, 'title'].iloc[0]
    top_books_list.append({'item_id': item_id, 'title': book_title, 'damped_mean_rating': top_books[item_id]})

top_books_df = pd.DataFrame(top_books_list)
top_books_df
# Out:
#     item_id                                              title  \
# 0     35178                What I've Done (Morgan Dane Book 4)
# 1     19942                                   The Wonky Donkey
# 2     19873                                What the Wind Knows
# 3      3593                                           Becoming
# 4     44721                  Giraffes Can't Dance (Board Book)
# 5     16590              Say You're Sorry (Morgan Dane Book 1)
# 6     26944                                     Girls of Glass
# 7     30472             Secrets Never Die (Morgan Dane Book 5)
# 8      6502                            Where the Crawdads Sing
# 9     47416                    Minutes to Kill (Scarlet Falls)
# 10    32201          A Merciful Fate (Mercy Kilpatrick Book 5)
# 11    35991                                           Run Away
# 12    49843  Close to the Bone (Widow's Island Novella Book 1)
# 13    36489                  The Storyteller's Secret: A Novel
# 14    46204                                     The Snow Gypsy
# 15    15626               First 100 Words: A Padded Board Book
# 16    43649  Dead Memories: An addictive and gripping crime...
# 17    33979            Blood for Blood (Ziba MacKenzie Book 1)
# 18     3929                     Dear Zoo: A Lift-the-Flap Book
# 19    10248                          Oh, the Places You'll Go!
#
#     damped_mean_rating
# 0             4.621212
# 1             4.594340
# 2             4.537313
# 3             4.463918
# 4             4.456522
# 5             4.439394
# 6             4.439394
# 7             4.431034
# 8             4.428571
# 9             4.404762
# 10            4.391892
# 11            4.388889
# 12            4.369565
# 13            4.367347
# 14            4.344262
# 15            4.324324
# 16            4.309524
# 17            4.304878
# 18            4.300000
# 19            4.264706

# %% [markdown]
# ### Content-based recommender based on K = 50 nearest neighbors (using any combination of features: I use only the book categories)

# %%
df_tags = merged_train_tags.drop('title',axis=1)
df_tags
# Out:
#         user_id  item_id              category      timestamp
# 0          3361    53296                 Books  1543536132144
# 1          3361    53296  Literature & Fiction  1543536132144
# 2          3361    53296    Action & Adventure  1543536132144
# 3          4471     1424                 Books  1543536168823
# 4          4471     1424      Children's Books  1543536168823
# ...         ...      ...                   ...            ...
# 262164     6954    53231  Literature & Fiction  1555050587832
# 262165     6954    53231              Classics  1555050587832
# 262166     6322    47262                 Books  1555050710933
# 262167     6322    47262  Literature & Fiction  1555050710933
# 262168     6322    47262         Genre Fiction  1555050710933
#
# [262169 rows x 4 columns]

# %%
df_ratings
# Out:
#        user_id  item_id                                              title  \
# 0         3361    53296                Crescent Dawn (Dirk Pitt Adventure)
# 1         4471     1424      Cars (Disney/Pixar Cars) (Little Golden Book)
# 2          342    50326  Love Coloring Book: An Adult Coloring Book wit...
# 3        10576     1953  Magic Tree House Boxed Set, Books 1-4: Dinosau...
# 4         3658     1953  Magic Tree House Boxed Set, Books 1-4: Dinosau...
# ...        ...      ...                                                ...
# 79085     8464    40568  Eternal Flame: A WWII-1980s Time Travel Love S...
# 79086     3840    56077  Moskva: 'The new Le Carre' BBC Radio 2 The Sar...
# 79087     6841    26078  Space Activity Book for Kids Ages 4-8: A Fun K...
# 79088     6954    53231                                Pride and Prejudice
# 79089     6322    47262       The Red Sword (The Red Sword Trilogy Book 1)
#
#        rating      timestamp
# 0         5.0  1543536132144
# 1         5.0  1543536168823
# 2         5.0  1543536419204
# 3         5.0  1543536938535
# 4         5.0  1546568460586
# ...       ...            ...
# 79085     4.0  1555050231806
# 79086     4.0  1555050392664
# 79087     5.0  1555050413806
# 79088     5.0  1555050587832
# 79089     5.0  1555050710933
#
# [79090 rows x 5 columns]

# %%
df_books = expanded_categories_df
df_books
# Out:
#         item_id                                              title  price  \
# 0             1                                    Parker & Knight    0.0
# 1             1                                    Parker & Knight    0.0
# 2             1                                    Parker & Knight    0.0
# 3             1                                    Parker & Knight    0.0
# 4             3                                           Jealousy    0.0
# ...         ...                                                ...    ...
# 185788    56947  The Secret Teachings of All Ages (Reader's Edi...  19.49
# 185789    56947  The Secret Teachings of All Ages (Reader's Edi...  19.49
# 185790    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
# 185791    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
# 185792    56948  Tennis Shoe Adventure series: Tennis Shoes Amo...   8.16
#
#                        category
# 0                         Books
# 1                       Mystery
# 2           Thriller & Suspense
# 3          Thrillers & Suspense
# 4                         Books
# ...                         ...
# 185788  Religion & Spirituality
# 185789     Literature & Fiction
# 185790                    Books
# 185791                  Mystery
# 185792      Thriller & Suspense
#
# [183267 rows x 4 columns]

# %%
#transform tags such that they are lower-case, single-word tokens
df_books['category'] = df_books['category'].apply(lambda x: str(x).lower().replace(' ', '_'))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2848\298071489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books['category'] = df_books['category'].apply(lambda x: str(x).lower().replace(' ', '_'))

# %% [markdown]
# ### Step1: Calculate item profiles

# %%
# calculates the lexicon of most frequent tags.
tag_frequency_threshold = 500
tag_counts = df_books['category'].value_counts()
df_lexicon = tag_counts[tag_counts >= tag_frequency_threshold].reset_index()
df_lexicon.columns = ['category', 'count']

# Filter df_tags to include only tags in the lexicon
df_tags_filtered = df_books[df_books['category'].isin(df_lexicon['category'])]

# Drop unnecessary columns
df_tags_filtered = df_tags_filtered.drop(columns=['title', 'price'], errors='ignore')

# %%
# uni = df_tags_filtered['category'].unique()
# len(uni)

# %%
#calculate the sparse feature vector based on the TF-IDF of words in documents
#the TF-IDF vectors are saved as sparse representations into the dataframe
df_features = df_tags_filtered.groupby('item_id')['category'].agg(lambda x: ' '.join(x)).reset_index()
vectorizer = TfidfVectorizer(tokenizer=lambda x: x.split(' ')).fit(sorted(df_features['category']))
vectorizer.vocabulary_
df_features['feature_vector'] = df_features['category'].apply(lambda x : vectorizer.transform([x]))
df_features
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
#        item_id                                           category  \
# 0            1  books mystery thriller_&_suspense thrillers_&_...
# 1            3  books mystery thriller_&_suspense thrillers_&_...
# 2            4                        books cookbooks food_&_wine
# 3            5                                      books history
# 4            6                     books arts_&_photography music
# ...        ...                                                ...
# 55927    56944                        books biographies_&_memoirs
# 55928    56945                     books children's_books history
# 55929    56946                           books arts_&_photography
# 55930    56947  books religion_&_spirituality literature_&_fic...
# 55931    56948                  books mystery thriller_&_suspense
#
#                                           feature_vector
# 0        (0, 43)\t0.6086229425420621\n  (0, 42)\t0.54...
# 1        (0, 43)\t0.6086229425420621\n  (0, 42)\t0.54...
# 2        (0, 19)\t0.6992576830001189\n  (0, 13)\t0.69...
# 3        (0, 24)\t0.9775049542055294\n  (0, 6)\t0.210...
# 4        (0, 30)\t0.773649364709597\n  (0, 6)\t0.1429...
# ...                                                  ...
# 55927    (0, 6)\t0.22188159751403277\n  (0, 5)\t0.975...
# 55928    (0, 24)\t0.8460677158230178\n  (0, 8)\t0.500...
# 55929    (0, 6)\t0.2255749752362588\n  (0, 4)\t0.9742...
# 55930    (0, 36)\t0.9074693422944268\n  (0, 29)\t0.38...
# 55931    (0, 42)\t0.685942622305675\n  (0, 31)\t0.686...
#
# [55932 rows x 3 columns]

# %%
# csr_matrix_feature_vec.nnz

# %%
# print("TF-IDF Matrix shape")
# len(vectorizer.vocabulary_)

# %%
#tfidf_matrix.nnz

# %%
# zero_elements_mask = df_features['feature_vector'].apply(lambda x: x.nnz == 0)
# num_rows_with_zero_elements = zero_elements_mask.sum()
# print("Number of rows with sparse matrices containing zero stored elements:", num_rows_with_zero_elements)

# %% [markdown]
# ### Step2: Index item profiles into LSH

# %%
print(df_features['feature_vector'].iloc[0].shape)
# Out:
# (1, 47)

# %%
feature_vectors = df_features['feature_vector'].tolist()
#feature_vectors

# %%
# #index all item vectors into LSH
matrix_feature_vec = vstack(feature_vectors)
csr_matrix_feature_vec = csr_matrix(matrix_feature_vec)

# %%
# # Ensure no rows with zero elements in CSR matrix
# non_zero_mask = csr_matrix_feature_vec.getnnz(axis=1) > 0
# csr_matrix_feature_vec = csr_matrix_feature_vec[non_zero_mask]

# %%
NUM_DIM = len(vectorizer.vocabulary_)
hash_size = 8
num_hashtables = 3

# Create LSH index
lsh = LSH(hash_size=hash_size, input_dim=NUM_DIM, num_hashtables=num_hashtables)

for i, row in df_features.iterrows():
    item_vector = csr_matrix_feature_vec[i]  # Access the item vector directly from the CSR matrix
    lsh.index(item_vector, extra_data=row['item_id'])

# %%
# Example query
query_vector = df_features.iloc[0]['feature_vector']
nearest_neighbors = lsh.query(query_vector, num_results=5)

# %%
nearest_neighbors_ids = [item[0][1] for item in nearest_neighbors]
nearest_neighbors_ids
# Out:
# [1, 3, 1, 56927, 56925]

# %%
neighbL = []
for i in nearest_neighbors_ids:
    # Access the row corresponding to the index i and convert it to a dictionary
    row_dict = df_b[df_b['item_id'] == i].iloc[0].to_dict()
    neighbL.append(row_dict)

# Convert the list into a DataFrame
neighb = pd.DataFrame(neighbL)

neighb
# Out:
#    item_id                                    title price  \
# 0        1                          Parker & Knight   0.0
# 1        3                                 Jealousy   0.0
# 2        1                          Parker & Knight   0.0
# 3    56927  4th of July (Women's Murder Club, No 4)  8.49
# 4    56925    A Killer's Alibi (Philadelphia Legal)  7.89
#
#                                           categories
# 0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 1  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 2  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 3  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 4  ['Books', 'Mystery, Thriller & Suspense', 'Thr...

# %% [markdown]
# ### Step 3: Calculate user profile

# %%
df_ratings
# Out:
#        user_id  item_id                                              title  \
# 0         3361    53296                Crescent Dawn (Dirk Pitt Adventure)
# 1         4471     1424      Cars (Disney/Pixar Cars) (Little Golden Book)
# 2          342    50326  Love Coloring Book: An Adult Coloring Book wit...
# 3        10576     1953  Magic Tree House Boxed Set, Books 1-4: Dinosau...
# 4         3658     1953  Magic Tree House Boxed Set, Books 1-4: Dinosau...
# ...        ...      ...                                                ...
# 79085     8464    40568  Eternal Flame: A WWII-1980s Time Travel Love S...
# 79086     3840    56077  Moskva: 'The new Le Carre' BBC Radio 2 The Sar...
# 79087     6841    26078  Space Activity Book for Kids Ages 4-8: A Fun K...
# 79088     6954    53231                                Pride and Prejudice
# 79089     6322    47262       The Red Sword (The Red Sword Trilogy Book 1)
#
#        rating      timestamp
# 0         5.0  1543536132144
# 1         5.0  1543536168823
# 2         5.0  1543536419204
# 3         5.0  1543536938535
# 4         5.0  1546568460586
# ...       ...            ...
# 79085     4.0  1555050231806
# 79086     4.0  1555050392664
# 79087     5.0  1555050413806
# 79088     5.0  1555050587832
# 79089     5.0  1555050710933
#
# [79090 rows x 5 columns]

# %%
# restricts the ratings to the set of most popular books (optional, not needed for content-based)
numratings_threshold = 3 #increase this number if you want to filter
df_item_popularity = df_ratings[['item_id','rating']].groupby('item_id').count().reset_index()
df_item_popularity.columns = ['item_id','count'] 
df_item_popularity = df_item_popularity.sort_values(by='count', ascending=False)
df_item_popularity = df_item_popularity[df_item_popularity['count'] >= numratings_threshold]
print(f'Number of books reduced from {len(df_ratings.item_id.unique())} to {len(df_item_popularity.item_id.unique())}')
df_ratings_1 = pd.merge(df_ratings, df_item_popularity, on='item_id', how='inner')[['user_id', 'item_id', 'rating']]
df_ratings_1 = df_ratings_1.sort_values(by='user_id')

df_ratings_1.head()
# Out:
# Number of books reduced from 45433 to 5480
#        user_id  item_id  rating
# 2486         2    47886     3.0
# 8140         2    13194     5.0
# 14707        2    26600     5.0
# 7084         2    10107     5.0
# 21881        2    42004     5.0

# %%
df_ratings_1['rating_scaled'] = df_ratings_1.groupby('user_id')['rating'].transform(lambda x: x - x.mean())

# %%
# Filter out rating_scaled = 0
df_ratings_1 = df_ratings_1[df_ratings_1['rating_scaled'] != 0]

# %%
df_profile = pd.merge(df_ratings_1, df_features[['item_id', 'feature_vector']], on='item_id')

# Scale feature vector by rating
df_profile['feature_vector_scaled'] = df_profile.apply(lambda row: row['rating_scaled'] * row['feature_vector'], axis=1)

# %%
uni = df_profile['user_id'].unique()
len(uni)
# Out:
# 3359

# %%
start = time.time()
#stack all sparse vectors of user's books
df_user_vectors = df_profile[['user_id', 'feature_vector_scaled']].groupby('user_id').agg(sparse.vstack).reset_index()
#compute the average of the vectors without considering the zero entries (this will take a while)
df_user_vectors['feature_vector_scaled'] = df_user_vectors['feature_vector_scaled'].apply(lambda x: csr_matrix(np.nan_to_num(x.sum(axis=0)/x.getnnz(axis=0), 0)))
end = time.time()
print(end - start)
df_user_vectors
# Out:
# 3.977790594100952
#       user_id                              feature_vector_scaled
# 0           2    (0, 0)\t-0.06319033569412447\n  (0, 5)\t-0.0...
# 1           6    (0, 1)\t0.08217123708168471\n  (0, 3)\t0.108...
# 2           9    (0, 0)\t0.821474364023621\n  (0, 6)\t-0.0081...
# 3          13    (0, 6)\t0.002069850377450097\n  (0, 31)\t0.0...
# 4          20    (0, 6)\t-0.0003196934492990306\n  (0, 25)\t0...
# ...       ...                                                ...
# 3354    13758    (0, 6)\t0.0034925896678157237\n  (0, 7)\t-0....
# 3355    13763    (0, 6)\t-0.0016062668798636746\n  (0, 7)\t0....
# 3356    13767    (0, 6)\t0.007411762130932002\n  (0, 20)\t0.1...
# 3357    13790
# 3358    13792    (0, 6)\t-3.053113317719181e-17\n  (0, 31)\t-...
#
# [3359 rows x 2 columns]

# %%
zero_elements_mask = df_user_vectors['feature_vector_scaled'].apply(lambda x: x.nnz == 0)
num_rows_with_zero_elements = zero_elements_mask.sum()

print("Number of rows with sparse matrices containing zero stored elements:", num_rows_with_zero_elements)
# Out:
# Number of rows with sparse matrices containing zero stored elements: 331

# %%
df_user_vectors
# Out:
#       user_id                              feature_vector_scaled
# 0           2    (0, 0)\t-0.06319033569412447\n  (0, 5)\t-0.0...
# 1           6    (0, 1)\t0.08217123708168471\n  (0, 3)\t0.108...
# 2           9    (0, 0)\t0.821474364023621\n  (0, 6)\t-0.0081...
# 3          13    (0, 6)\t0.002069850377450097\n  (0, 31)\t0.0...
# 4          20    (0, 6)\t-0.0003196934492990306\n  (0, 25)\t0...
# ...       ...                                                ...
# 3354    13758    (0, 6)\t0.0034925896678157237\n  (0, 7)\t-0....
# 3355    13763    (0, 6)\t-0.0016062668798636746\n  (0, 7)\t0....
# 3356    13767    (0, 6)\t0.007411762130932002\n  (0, 20)\t0.1...
# 3357    13790
# 3358    13792    (0, 6)\t-3.053113317719181e-17\n  (0, 31)\t-...
#
# [3359 rows x 2 columns]

# %% [markdown]
# ### Step 4: Rank potential recommendation candidates
# • Select a target user to provide recommendations to
# • Query LSH with the user vector get a rank of candidate items
# (Use sparse vector representations if needed)

# %%
# Picking a target user to provide recommendations
idx = 700
target_user_id = df_user_vectors.iloc[idx]['user_id']

# Get user rating history
df_user_history = df_ratings[df_ratings['user_id'] == target_user_id]

# Select candidate recommendations for the user
df_recommendation = df_features[~df_features['item_id'].isin(df_user_history['item_id'])]
user_vector = df_user_vectors[df_user_vectors['user_id'] == target_user_id]['feature_vector_scaled'].values[0]

# Query LSH with the user vector
candidate_items = lsh.query(user_vector, num_results=20)
candidate_item_ids = [item[0][1] for item in candidate_items]

df_candidate_recommendations = df_recommendation[df_recommendation['item_id'].isin(candidate_item_ids)]
#print("Candidate Recommendations:")
#df_candidate_recommendations

# %%
user = pd.merge(df_user_history, df_b, on='item_id')
user
# Out:
#     user_id  item_id                                            title_x  \
# 0      2194     2485                  Paradox (An FBI Thriller Book 22)
# 1      2194    32424  Murder in Park Lane (The Detective Lavender My...
# 2      2194     7621                                 The Beantown Girls
# 3      2194    42749  THE OXFORD MYSTERY an absolutely gripping whod...
# 4      2194    53559                         The Moroccan Girl: A Novel
# 5      2194     6119                              The Light Over London
# 6      2194     1487            The Last Second (6) (A Brit in the FBI)
# 7      2194    37747                                Night of Camp David
# 8      2194     7708  THE WINTER MYSTERY an absolutely gripping whod...
# 9      2194    15377  THE RIVERBOAT MYSTERY an absolutely gripping w...
# 10     2194    43993  Sidney Sheldon's The Silent Widow: A Sidney Sh...
# 11     2194    31076  The Scent of Murder: A Mystery (A Jazz Ramsey ...
# 12     2194    25073  MURDER IN THE MINE a gripping crime mystery fu...
# 13     2194    16127  Open Carry: An Action Packed US Marshal Suspen...
# 14     2194    12399                                   Missing Daughter
# 15     2194    14799                The Shadow Agent (The Agent Book 3)
# 16     2194    17738  A Deeper Darkness: A Novel (A Samantha Owens N...
# 17     2194    39068      Edge of Black (A Samantha Owens Novel Book 2)
# 18     2194    31857  THE CASTLE MYSTERY an absolutely gripping whod...
# 19     2194    28190                      Infidel (A Kane Novel Book 5)
#
#     rating      timestamp                                            title_y  \
# 0      5.0  1550237368244                  Paradox (An FBI Thriller Book 22)
# 1      5.0  1543639200826  Murder in Park Lane (The Detective Lavender My...
# 2      5.0  1548955398697                                 The Beantown Girls
# 3      4.0  1547917185944  THE OXFORD MYSTERY an absolutely gripping whod...
# 4      4.0  1554947939625                         The Moroccan Girl: A Novel
# 5      5.0  1546131607007                              The Light Over London
# 6      5.0  1548167431945            The Last Second (6) (A Brit in the FBI)
# 7      5.0  1553280637128                                Night of Camp David
# 8      5.0  1554841907021  THE WINTER MYSTERY an absolutely gripping whod...
# 9      5.0  1544588267589  THE RIVERBOAT MYSTERY an absolutely gripping w...
# 10     5.0  1550720929527  Sidney Sheldon's The Silent Widow: A Sidney Sh...
# 11     4.0  1546063711852  The Scent of Murder: A Mystery (A Jazz Ramsey ...
# 12     5.0  1553293141526  MURDER IN THE MINE a gripping crime mystery fu...
# 13     5.0  1547565863042  Open Carry: An Action Packed US Marshal Suspen...
# 14     5.0  1546929755891                                   Missing Daughter
# 15     5.0  1548644928716                The Shadow Agent (The Agent Book 3)
# 16     5.0  1550365522734  A Deeper Darkness: A Novel (A Samantha Owens N...
# 17     5.0  1551441756767      Edge of Black (A Samantha Owens Novel Book 2)
# 18     5.0  1552073800073  THE CASTLE MYSTERY an absolutely gripping whod...
# 19     5.0  1554360069249                      Infidel (A Kane Novel Book 5)
#
#     price                                         categories
# 0   11.99  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 1     0.0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 2     0.0  ['Books', 'Literature & Fiction', 'Genre Ficti...
# 3     0.0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 4    9.49  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 5    9.99  ['Books', 'Literature & Fiction', 'Genre Ficti...
# 6   14.73  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 7    7.99  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 8     0.0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 9     0.0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 10   None  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 11  17.65  ['Books', 'Mystery, Thriller & Suspense', 'Mys...
# 12    0.0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 13  11.97  ['Books', 'Literature & Fiction', 'Action & Ad...
# 14   1.99  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 15    0.0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 16   1.99  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 17  14.49  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 18   8.24  ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 19    0.0  ['Books', 'Mystery, Thriller & Suspense', 'Thr...

# %%
df_candidates = pd.merge(df_candidate_recommendations, df_b, on='item_id')
df_candidates = df_candidates[['item_id', 'title', 'category']]
df_candidates
# Out:
#     item_id                                              title  \
# 0     28100  Age of Swords: Book Two of The Legends of the ...
# 1     36195  The Protocol: A James Acton Thriller (James Ac...
# 2     36239                        Mission Critical (Gray Man)
# 3     36249             The Last Wish: Introducing The Witcher
# 4     36252  The Girl in the Tower: A Novel (Winternight Tr...
# 5     36294                          Agent in Place (Gray Man)
# 6     36343                          The Man Who Would Be King
# 7     36601        Ice Forged (The Ascendant Kingdoms Saga, 1)
# 8     36615               Scourged (The Iron Druid Chronicles)
# 9     36696                  Call of the Six (The Preston Six)
# 10    36896             The Steel Shark (Joe Tesla) (Volume 4)
# 11    36934                    Endgame: Arisen series, Book 14
# 12    36953                                   Hearts and Minds
# 13    36976           The Cornwalls Are Gone (Amy Cornwall, 1)
# 14    37045       Spellbook Cards: Ranger (Dungeons & Dragons)
# 15    37047                                    Tarnsman of Gor
# 16    37085                The Night Window: A Jane Hawk Novel
# 17    37112                                Slaughter of Eagles
# 18    37785  Fool's Assassin: Book I of the Fitz and the Fo...
# 19    37838  James Fenimore Cooper: The Leatherstocking Tal...
#
#                                          category
# 0   books literature_&_fiction action_&_adventure
# 1   books literature_&_fiction action_&_adventure
# 2   books literature_&_fiction action_&_adventure
# 3   books literature_&_fiction action_&_adventure
# 4   books literature_&_fiction action_&_adventure
# 5   books literature_&_fiction action_&_adventure
# 6   books literature_&_fiction action_&_adventure
# 7   books literature_&_fiction action_&_adventure
# 8   books literature_&_fiction action_&_adventure
# 9   books literature_&_fiction action_&_adventure
# 10  books literature_&_fiction action_&_adventure
# 11  books literature_&_fiction action_&_adventure
# 12  books literature_&_fiction action_&_adventure
# 13  books literature_&_fiction action_&_adventure
# 14  books literature_&_fiction action_&_adventure
# 15  books literature_&_fiction action_&_adventure
# 16  books literature_&_fiction action_&_adventure
# 17  books literature_&_fiction action_&_adventure
# 18  books literature_&_fiction action_&_adventure
# 19  books literature_&_fiction action_&_adventure

# %% [markdown]
# ### Step 5: Predict ratings of candidate items
# • Create another LSH index for users
# • Query the user LSH index with the vectors of each recommended book to estimate the predicted rating based on k-nearest neighbor

# %%
# Create an LSH index for user profile vectors
# input_dim = len(vectorizer.vocabulary_)
# hash_size_user = 10  
# num_hashtables_user = 3  

# user_lsh = LSH(hash_size=hash_size_user, input_dim=input_dim, num_hashtables=num_hashtables_user)

# for i, row in df_user_vectors.iterrows():
#     user_vector = row['feature_vector_scaled']
#     user_lsh.index(user_vector, extra_data=row['user_id'])

# %%
# Back-up when the recommended books have no ratings ^.^'
df_user_avg_rating = df_ratings.groupby('user_id')['rating'].mean().reset_index()
df_user_avg_rating.columns = ['user_id', 'avg_rating']

# %%
predicted_ratings = []

for idx, row in df_candidate_recommendations.iterrows():
    book_id = row['item_id']
    book_vector = row['feature_vector']

    similar_users = user_lsh.query(book_vector, num_results=50)  
    similar_user_info = [(item[0][1], item[1]) for item in similar_users]  # (similarity_score, user_id)
    similar_user_ids = [info[0] for info in similar_user_info]

    similar_user_ratings = df_ratings[(df_ratings['user_id'].isin(similar_user_ids)) & (df_ratings['item_id'] == book_id)]
    
    if not similar_user_ratings.empty:
        # Compute the weighted average rating
        rating_sum = 0
        weight_sum = 0
        for user_id, similarity_score in similar_user_info:
            user_rating_row = similar_user_ratings[similar_user_ratings['user_id'] == user_id]
            if not user_rating_row.empty:
                user_rating = user_rating_row['rating'].values[0]
                rating_sum += similarity_score * user_rating
                weight_sum += similarity_score
        
        predicted_rating = rating_sum / weight_sum if weight_sum != 0 else 0
    else:
        target_user_avg_rating = df_user_avg_rating[df_user_avg_rating['user_id'] == target_user_id]['avg_rating'].values[0]
        predicted_rating = target_user_avg_rating

    predicted_ratings.append((book_id, predicted_rating))

# %%
df_predicted_ratings = pd.DataFrame(predicted_ratings, columns=['item_id', 'predicted_rating'])
df_final_recommendations = pd.merge(df_candidates, df_predicted_ratings, on='item_id')
df_final_recommendations = df_final_recommendations.sort_values(by='predicted_rating', ascending=False)
df_final_recommendations
# Out:
#     item_id                                              title  \
# 16    37085                The Night Window: A Jane Hawk Novel
# 3     36249             The Last Wish: Introducing The Witcher
# 0     28100  Age of Swords: Book Two of The Legends of the ...
# 11    36934                    Endgame: Arisen series, Book 14
# 18    37785  Fool's Assassin: Book I of the Fitz and the Fo...
# 17    37112                                Slaughter of Eagles
# 15    37047                                    Tarnsman of Gor
# 14    37045       Spellbook Cards: Ranger (Dungeons & Dragons)
# 13    36976           The Cornwalls Are Gone (Amy Cornwall, 1)
# 12    36953                                   Hearts and Minds
# 10    36896             The Steel Shark (Joe Tesla) (Volume 4)
# 1     36195  The Protocol: A James Acton Thriller (James Ac...
# 9     36696                  Call of the Six (The Preston Six)
# 8     36615               Scourged (The Iron Druid Chronicles)
# 7     36601        Ice Forged (The Ascendant Kingdoms Saga, 1)
# 6     36343                          The Man Who Would Be King
# 5     36294                          Agent in Place (Gray Man)
# 4     36252  The Girl in the Tower: A Novel (Winternight Tr...
# 2     36239                        Mission Critical (Gray Man)
# 19    37838  James Fenimore Cooper: The Leatherstocking Tal...
#
#                                          category  predicted_rating
# 16  books literature_&_fiction action_&_adventure              5.00
# 3   books literature_&_fiction action_&_adventure              5.00
# 0   books literature_&_fiction action_&_adventure              4.85
# 11  books literature_&_fiction action_&_adventure              4.85
# 18  books literature_&_fiction action_&_adventure              4.85
# 17  books literature_&_fiction action_&_adventure              4.85
# 15  books literature_&_fiction action_&_adventure              4.85
# 14  books literature_&_fiction action_&_adventure              4.85
# 13  books literature_&_fiction action_&_adventure              4.85
# 12  books literature_&_fiction action_&_adventure              4.85
# 10  books literature_&_fiction action_&_adventure              4.85
# 1   books literature_&_fiction action_&_adventure              4.85
# 9   books literature_&_fiction action_&_adventure              4.85
# 8   books literature_&_fiction action_&_adventure              4.85
# 7   books literature_&_fiction action_&_adventure              4.85
# 6   books literature_&_fiction action_&_adventure              4.85
# 5   books literature_&_fiction action_&_adventure              4.85
# 4   books literature_&_fiction action_&_adventure              4.85
# 2   books literature_&_fiction action_&_adventure              4.85
# 19  books literature_&_fiction action_&_adventure              4.85

# %% [markdown]
# ### User-User collaborative Filtering

# %%
train_df = pd.merge(ratings_train_df, df_b[['item_id','title','categories']],
              on='item_id').drop('timestamp', axis=1)
train_df
test_df = pd.merge(ratings_train_df, df_b[['item_id','title','categories']],
              on='item_id').drop('timestamp', axis=1)

# %%
reader = Reader(rating_scale=(1, 5))

# Load the data from the DataFrame
train = Dataset.load_from_df(train_df[['user_id', 'item_id', 'rating']], reader)
test = Dataset.load_from_df(test_df[['user_id', 'item_id', 'rating']], reader)

# %%
# Build the trainset
trainset = train.build_full_trainset()
testset = test.build_full_trainset().build_testset()

# %%
# Use k-NN algorithm with user-based collaborative filtering and cosine similarity
kk = 50
sim_options = {'name': 'cosine', 'user_based': True, 'min_support': 2 }
algo = KNNBasic(k = kk, sim_options = sim_options, verbose = True)

# %%
algo.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
def get_top_n_neighbors(user_id, n):
    inner_id = algo.trainset.to_inner_uid(user_id)
    user_inner_ids = algo.trainset.all_users()
    
    similarities = []
    for other_inner_id in user_inner_ids:
        if inner_id != other_inner_id:
            similarity = algo.sim[inner_id, other_inner_id]
            similarities.append((algo.trainset.to_raw_uid(other_inner_id), similarity))
    
    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities[1:n+1]

# %%
def get_recommendations(user_id, top_n_neighbors, num_recommendations):
    user_inner_id = algo.trainset.to_inner_uid(user_id)
    user_rated_items = set(item_id for item_id, _ in algo.trainset.ur[user_inner_id])

    #print(user_rated_items)
    all_items = algo.trainset.all_items()
    recommendations = []
    
    for item_inner_id in all_items:
        item_raw_id = algo.trainset.to_raw_iid(item_inner_id)
        if item_inner_id not in user_rated_items:
            estimated_rating = algo.predict(user_id, item_raw_id).est
            recommendations.append((item_raw_id, estimated_rating))
    
    recommendations.sort(key=lambda x: x[1], reverse=True)
    
    return [(item, rating) for item, rating in recommendations[:num_recommendations]]

# %%
# Get top N neighbors for a specific user
user_id = 1300
top_n_neighbors = get_top_n_neighbors(user_id, n=20)
num_recommendations = 20

# %%
uni = train_df[train_df['user_id']==1300]
uni
# Out:
#        user_id  item_id  rating  \
# 11778     1300     3196     5.0
# 16657     1300     1062     5.0
# 23065     1300    28076     5.0
# 41512     1300    36812     5.0
# 42748     1300    49563     5.0
# 44868     1300    36885     5.0
#
#                                                    title  \
# 11778                         This book just ate my dog!
# 16657                            Good Morning, Snowplow!
# 23065  FIREBOAT: The Heroic Adventures of the John J....
# 41512                                         Round Trip
# 42748   Mary Who Wrote Frankenstein (Who Wrote Classics)
# 44868                 The Wall in the Middle of the Book
#
#                                               categories
# 11778           ['Books', "Children's Books", 'Animals']
# 16657  ['Books', "Children's Books", 'Science, Nature...
# 23065           ['Books', "Children's Books", 'History']
# 41512  ['Books', "Children's Books", 'Arts, Music & P...
# 42748  ['Books', "Children's Books", 'Growing Up & Fa...
# 44868  ['Books', "Children's Books", 'Growing Up & Fa...

# %%
recommendations = get_recommendations(user_id, top_n_neighbors, 20)

# %%
rec = pd.DataFrame(recommendations, columns=['item_id', 'estimated_rating'])
rec_uu = pd.merge(rec, df_b[['item_id','title','categories']], on='item_id')
# Print the DataFrame
rec_uu
# Out:
#     item_id  estimated_rating  \
# 0     19942                 5
# 1     51566                 5
# 2     51620                 5
# 3     14290                 5
# 4     45499                 5
# 5     40290                 5
# 6      3130                 5
# 7     49764                 5
# 8     24596                 5
# 9     30936                 5
# 10    45667                 5
# 11    11938                 5
# 12    56155                 5
# 13    20949                 5
# 14    39054                 5
# 15    41322                 5
# 16    39781                 5
# 17    27125                 5
# 18    23870                 5
# 19     2332                 5
#
#                                                 title  \
# 0                                    The Wonky Donkey
# 1                        Parts (Picture Puffin Books)
# 2                                  The Night Gardener
# 3                                  The Silent Patient
# 4       We Are in a Book!-An Elephant and Piggie Book
# 5   What Do You Do With a Chance? — New York Times...
# 6                                  Gone with the Wind
# 7                                Tiny, Perfect Things
# 8                                 Good Night, Gorilla
# 9        Ed Emberley's Complete Funprint Drawing Book
# 10                          A Sick Day for Amos McGee
# 11                                Dragon Was Terrible
# 12                            If I Had a Little Dream
# 13                        Chrysalis (Project Nemesis)
# 14                                    Stick and Stone
# 15                                           Leaf Man
# 16                                The Rabbit Listened
# 17  Year of Yes: How to Dance It Out, Stand In the...
# 18  The Little Grumpy Cat that Wouldn't (Grumpy Ca...
# 19                     Lola Dutch (Lola Dutch Series)
#
#                                            categories
# 0            ['Books', "Children's Books", 'Animals']
# 1   ['Books', "Children's Books", 'Growing Up & Fa...
# 2   ['Books', "Children's Books", 'Arts, Music & P...
# 3   ['Books', 'Mystery, Thriller & Suspense', 'Thr...
# 4   ['Books', "Children's Books", 'Growing Up & Fa...
# 5   ['Books', "Children's Books", 'Growing Up & Fa...
# 6   ['Books', 'Literature & Fiction', 'Genre Ficti...
# 7   ['Books', "Children's Books", 'Growing Up & Fa...
# 8   ['Books', "Children's Books", 'Growing Up & Fa...
# 9   ['Books', "Children's Books", 'Arts, Music & P...
# 10  ['Books', "Children's Books", 'Growing Up & Fa...
# 11  ['Books', "Children's Books", 'Growing Up & Fa...
# 12  ['Books', "Children's Books", 'Growing Up & Fa...
# 13  ['Books', 'Teen & Young Adult', 'Literature & ...
# 14  ['Books', "Children's Books", 'Growing Up & Fa...
# 15  ['Books', "Children's Books", 'Arts, Music & P...
# 16  ['Books', "Children's Books", 'Growing Up & Fa...
# 17  ['Books', 'Biographies & Memoirs', 'Arts & Lit...
# 18  ['Books', "Children's Books", 'Growing Up & Fa...
# 19  ['Books', "Children's Books", 'Arts, Music & P...

# %% [markdown]
# ### SVD

# %%
svd = SVD(n_epochs=10)
results = cross_validate(svd, train, measures=['RMSE', 'MAE'], cv=10, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 10 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Fold 6  Fold 7  Fold 8  Fold 9  Fold 10 Mean    Std
# RMSE (testset)    0.7961  0.7803  0.7993  0.8257  0.7963  0.7942  0.7928  0.8223  0.7975  0.8000  0.8005  0.0129
# MAE (testset)     0.5931  0.5831  0.5945  0.6019  0.5892  0.5905  0.5888  0.6013  0.5882  0.5892  0.5920  0.0056
# Fit time          1.41    1.40    1.39    1.39    1.40    1.40    1.38    1.39    1.42    1.38    1.40    0.01
# Test time         0.10    0.11    0.10    0.10    0.10    0.11    0.11    0.11    0.10    0.11    0.10    0.00

# %%
svd.fit(trainset)

# %%
# Map original IDs to internal IDs
raw_id_to_inner_id = {raw_id: inner_id for raw_id, inner_id in trainset._raw2inner_id_items.items()}

# %%
def generate_recommendation(model, user_id, ratings_df, books_df, n_items):
    book_ids = ratings_df["item_id"].unique()
    book_ids_user = ratings_df.loc[ratings_df["user_id"] == user_id, "item_id"]
    book_ids_to_pred = np.setdiff1d(book_ids, book_ids_user)
    
    # Map book_ids_to_pred to internal IDs
    book_ids_to_pred_internal = [raw_id_to_inner_id[book_id] for book_id in book_ids_to_pred if book_id in raw_id_to_inner_id]
    
    test_set = [(user_id, book_id, 4) for book_id in book_ids_to_pred_internal]
    predictions = model.test(test_set)

    pred_ratings = np.array([pred.est for pred in predictions])

    
    index_max = (-pred_ratings).argsort()[:n_items]
    recommendations = []
    for i in index_max:
        if i >= len(book_ids_to_pred_internal):
            print(f"Index {i} is out of bounds for book_ids_to_pred_internal of size {len(book_ids_to_pred_internal)}")
            continue
        book_id_internal = book_ids_to_pred_internal[i]
        book_id = next(key for key, value in raw_id_to_inner_id.items() if value == book_id_internal)
        book_title = books_df[books_df["item_id"] == book_id]["title"].values
        if len(book_title) > 0:
            recommendations.append({
                'item_id': book_id,
                'title': book_title[0],
                'predicted_rating': pred_ratings[i]
            })
        else:
            print(f"Book ID {book_id} not found in books_df")

    recommendations_df = pd.DataFrame(recommendations)
    return recommendations_df

# %%
# Finding 20 recommendation for userID = 2
userID = 2
n_items = 20
rec_svd = generate_recommendation(svd,userID,test_df,df_b,n_items)
rec_svd = pd.merge(rec_svd, df_b[['item_id','title', 'categories']], on=['item_id', 'title'])

# %%
rec_svd
# Out:
#     item_id                                              title  \
# 0     42882  Fodor's New Orleans 2016 (Full-color Travel Gu...
# 1     15940  Real Food for Dogs: 50 Vet-Approved Recipes fo...
# 2     30476  Large Print Word-Finds Puzzle Book-Word Search...
# 3     42636                                        Yellow Star
# 4     35503                                   The Husband Hour
# 5     34592  How to Lose an Alien in 10 Days (Alienn, Arkan...
# 6     27420     The Unlikely Pilgrimage of Harold Fry: A Novel
# 7      7406                         The Richest Man in Babylon
# 8     31470                         Moreta: Dragonlady of Pern
# 9     12905  The Black Hole War: My Battle with Stephen Haw...
# 10    49232  Around My French Table: More than 300 Recipes ...
# 11    18358                       Whistle in the Dark: A Novel
# 12    35994        Appalachian Prey (Lavender Mountain Book 1)
# 13    19888  The Silent Wife: A gripping emotional page tur...
# 14    30741  Snakes, Salamanders & Lizards (Take Along Guides)
# 15    20095  The Poison Squad: One Chemist's Single-Minded ...
# 16      640                 Breaking Silence (Kate Burkholder)
# 17     5059  Vocabulary Cartoon of the Day: Grades 4–6: 180...
# 18    40606                                        The Can Man
# 19     3920                            Froggy's Lemonade Stand
#
#     predicted_rating                                         categories
# 0           5.000000               ['Books', 'Travel', 'United States']
# 1           5.000000  ['Books', 'Crafts, Hobbies & Home', 'Pets & An...
# 2           5.000000  ['Books', 'Humor & Entertainment', 'Puzzles & ...
# 3           5.000000  ['Books', 'Teen & Young Adult', 'Literature & ...
# 4           4.993249  ['Books', 'Literature & Fiction', 'Genre Ficti...
# 5           4.984946                 ['Books', 'Romance', 'Paranormal']
# 6           4.975693  ['Books', 'Literature & Fiction', 'Genre Ficti...
# 7           4.971660  ['Books', 'Business & Money', 'Business Culture']
# 8           4.960599  ['Books', 'Literature & Fiction', 'Action & Ad...
# 9           4.955670  ['Books', 'Biographies & Memoirs', 'Profession...
# 10          4.951656  ['Books', 'Cookbooks, Food & Wine', 'Regional ...
# 11          4.950844  ['Books', 'Literature & Fiction', 'Genre Ficti...
# 12          4.948901  ['Books', 'Mystery, Thriller & Suspense', 'Mys...
# 13          4.947160               ['Books', 'Romance', 'Contemporary']
# 14          4.942053           ['Books', "Children's Books", 'Animals']
# 15          4.941406  ['Books', 'Politics & Social Sciences', 'Polit...
# 16          4.940637  ['Books', 'Mystery, Thriller & Suspense', 'Mys...
# 17          4.934974  ['Books', 'Reference', 'Words, Language & Gram...
# 18          4.930592  ['Books', "Children's Books", 'Growing Up & Fa...
# 19          4.929539  ['Books', "Children's Books", 'Growing Up & Fa...
