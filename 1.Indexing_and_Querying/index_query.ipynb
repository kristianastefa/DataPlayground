# %% [markdown]
# ## Indexing and querying the ratebeer dataset using ElasticSearch

# %%
import pandas as pd
import json
import requests
import numpy as np
from requests.auth import HTTPBasicAuth
from elasticsearch import Elasticsearch
import elasticsearch
from elasticsearch.helpers import bulk

print(elasticsearch.__version__)
# Out:
# (8, 12, 0)

# %%
# !!! CUSTOMIZE THIS SECTION WITH YOUR CREDENTIALS !!!

USER = 'elastic'
PWD = #confidential
index_name = 'beers'
ES_ENDPOINT = 'https://localhost:9200'

path_to_ca_certificates = 'C:/Users/user/pathtothefolder/elasticsearch-8.12.0/config/certs/http_ca.crt'

# %% [markdown]
# ### Read data

# %%
df_dup = pd.read_csv('../data/ratebeer/ratebeer.csv', index_col = False)
#df = df.set_index('beer_name')
df_dup
# Out:
#                                           beer_name            beer_style  \
# 0                             Sierra Nevada Bigfoot           Barley Wine
# 1                                          Icehouse            Pale Lager
# 2                   St Georges Paragon Steam Bitter     California Common
# 3                                Ayinger Bru-Weisse     German Hefeweizen
# 4                            Great Divide Titan IPA  India Pale Ale (IPA)
# ...                                             ...                   ...
# 584828               Smiling Moose Mooseberry Wheat            Fruit Beer
# 584829                      Deschutes The Dissident     Sour Ale/Wild Ale
# 584830                               Stroud Budding  Golden Ale/Blond Ale
# 584831  Brakspear Oxford Gold Organic Beer (Bottle)                Bitter
# 584832                        De Dolle Stille Nacht    Belgian Strong Ale
#
#        beer_ABV  review_appearance  review_aroma  review_palate  review_taste  \
# 0           9.6                  5             7              4             7
# 1           5.5                  3             2              1             1
# 2             4                  3             3              3             6
# 3           5.1                  5             8              5             8
# 4           7.1                  3             7              4             8
# ...         ...                ...           ...            ...           ...
# 584828        -                  3             6              3             6
# 584829     10.5                  4             8              3             7
# 584830      4.5                  3             6              3             6
# 584831      4.6                  3             4              3             6
# 584832       12                  5             9              5             9
#
#         review_overall review_profileName  \
# 0                   15            Juancho
# 1                    1              xav33
# 2                   10             hughie
# 3                   15           jredmond
# 4                   16          gringo332
# ...                ...                ...
# 584828              12             Ernest
# 584829              15          tokyogoat
# 584830              12         leaparsons
# 584831              11               TEJA
# 584832              19     stefanberggren
#
#                                               review_text
# 0       Draught \tThe big boy from Sierra Nevada. Nice...
# 1       Icehouse\tDeuce-Deuce\tRecent browing, resided...
# 2       Cask at Wellington Arms, Bedford. Gold with a ...
# 3       500mL Bottle. 2nd of 13 for the night. Body is...
# 4       Bottle. Pours golden/orange with a small white...
# ...                                                   ...
# 584828  Draught. Body is hazy medium yellow. Aroma is ...
# 584829  poured a burnt ruby orange. Nose was vinegary ...
# 584830  Bottle.  Golden brown with a thin foam.  Aroma...
# 584831  Big but short foam that dies down too a thin l...
# 584832  This beer was recommended by my local beer/win...
#
# [584833 rows x 10 columns]

# %% [markdown]
# ### Data Processing

# %%
duplicates = df_dup.duplicated().sum()
print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 2784

# %%
# Remove duplicates
df = df_dup.drop_duplicates()

# %%
# Replace various representations of empty values with None
df.replace(['', ' ', '-', np.nan], None, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12880\4141127485.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace(['', ' ', '-', np.nan], None, inplace=True)

# %%
# Creating a new column id to index by that
df.reset_index(inplace=True)
df.rename(columns={'index': 'id'}, inplace=True)
df.index.name = "id"
df = df.set_index('id')
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12880\1759020812.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'index': 'id'}, inplace=True)
#                           beer_name            beer_style beer_ABV  \
# id
# 0             Sierra Nevada Bigfoot           Barley Wine      9.6
# 1                          Icehouse            Pale Lager      5.5
# 2   St Georges Paragon Steam Bitter     California Common        4
# 3                Ayinger Bru-Weisse     German Hefeweizen      5.1
# 4            Great Divide Titan IPA  India Pale Ale (IPA)      7.1
#
#     review_appearance  review_aroma  review_palate  review_taste  \
# id
# 0                   5             7              4             7
# 1                   3             2              1             1
# 2                   3             3              3             6
# 3                   5             8              5             8
# 4                   3             7              4             8
#
#     review_overall review_profileName  \
# id
# 0               15            Juancho
# 1                1              xav33
# 2               10             hughie
# 3               15           jredmond
# 4               16          gringo332
#
#                                           review_text
# id
# 0   Draught \tThe big boy from Sierra Nevada. Nice...
# 1   Icehouse\tDeuce-Deuce\tRecent browing, resided...
# 2   Cask at Wellington Arms, Bedford. Gold with a ...
# 3   500mL Bottle. 2nd of 13 for the night. Body is...
# 4   Bottle. Pours golden/orange with a small white...

# %%
docs = df.to_dict(orient='records')
doc_ids = df.index
print(doc_ids[1])
print(docs[1])
# Out:
# 1
# {'beer_name': 'Icehouse', 'beer_style': 'Pale Lager', 'beer_ABV': '5.5', 'review_appearance': 3, 'review_aroma': 2, 'review_palate': 1, 'review_taste': 1, 'review_overall': 1, 'review_profileName': 'xav33', 'review_text': 'Icehouse\tDeuce-Deuce\tRecent browing, resided in 11/06\tMedium pour in a pint glass.\t\tPoured a slightly pale yellow with a fizzy mostly diminishing white head.\t\tSmelt of faint grain. \t\tTaste was upfront sweet drainage water with maybe hints of grain flavoring followed by an execrable harsh bitter fat mans bat tub water taste.  Mouthfeel was light bodied, watery-ish, fizzy and strongly astringent on the finish.\t\tOverall, I never actually tasted this beer until today.  Ive drank it a few times and thought it was ok, but never *tasted* it.  Dont taste it.  Just enjoy the buzz.'}

# %% [markdown]
# ### Indexing with python cURL (Requests)

# %%
class Elastic:
    """
    A convenience object to send HTTP requests to Elasticsearch
    """
    def __init__(self, endpoint, username, password, path_to_ca_certificates):
        """
        @param endpoint: the URL of the Elasticsearch instance
        @param username: the Elasticsearch username 
        @param password: the Elasticsearch password
        """
        self.header = {'Content-Type': 'application/json', 'charset':'UTF-8'}
        #self.header={'Content-Type': '--data-binary application/x-ndjson'}
        self.endpoint = endpoint
        self.username = username
        self.password = password
        self.path_to_ca_certificates = path_to_ca_certificates
        self.methods_mapping = {'get': requests.get, 
                                'put':requests.put, 
                                'post':requests.post, 
                                'delete':requests.delete}
        
    def curl(self, method, handle, json=None):
        """
        Sends an HTTP request to the Elasticsearch instance
        @param method: can be 'get', 'put', 'post', 'delete'
        @param handle: the API handle to be appended to the Elasticsearch url
        @param json: the json payload of the HTTP request
        """
        http_method = self.methods_mapping[method.lower()]
        r = http_method(f'{self.endpoint}/{handle}', auth=HTTPBasicAuth(USER, PWD), 
                        headers=self.header, json=json,
                        verify = self.path_to_ca_certificates)
        return r

# %%
e = Elastic(ES_ENDPOINT, USER, PWD, path_to_ca_certificates)

# %%
create_index_json={
# Point #4 By putting the type text to beer_name and review_text we allow for full-text query
    # while for beer_style we put keyword to omake it useful for filtering creating a DocValue
  "mappings" : {
      "properties" : {
        "beer_name" : {
          "type" : "text" 
        },
        "beer_style" : {
          "type" : "keyword"
        },
        "beer_ABV" : {
          "type" : "float"
        },
        "review_appearance" : {
          "type" : "integer"
        },
        "review_aromaa" : {
          "type" : "integer"
        },
        "review_palate" : {
          "type" : "integer"
        },
        "review_taste" : {
          "type" : "integer"
        },
          "review_overall" : {
          "type" : "integer"
        },
        "review_profileName" : {
          "type" : "text"
        },
        "review_text" : {
          "type" : "text"
        }
      }
  },
  "settings": {
    "refresh_interval": "-1", # Point #2 making a static database I removed the refreshing setting, by putting it to -1 (continued down)
    "number_of_shards": 4, 
    "number_of_replicas": 0, # Point #3  no replicas
    "index.max_result_window": 20000,
    "index" : {
        "similarity" : {
          "default" : {
            "type" : "BM25", "b": 0.825, "k1": 1.2 
    # Point #5 relevance metric is BM25, from default b=0.75 we increase by 10% to 0.825 
          }
        }
    },
    "analysis": {
      "analyzer": {
        "std_english": {"type": "standard", "stopwords": "_english_" }
      }
    }
  }
}

# create an index
r = e.curl('put', index_name, json=create_index_json)
r.json()
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'beers'}

# %%
# get the index details and settings
r = e.curl('get', index_name)
r.json()
# Out:
# {'beers': {'aliases': {},
#   'mappings': {'properties': {'beer_ABV': {'type': 'float'},
#     'beer_name': {'type': 'text'},
#     'beer_style': {'type': 'keyword'},
#     'review_appearance': {'type': 'integer'},
#     'review_aromaa': {'type': 'integer'},
#     'review_overall': {'type': 'integer'},
#     'review_palate': {'type': 'integer'},
#     'review_profileName': {'type': 'text'},
#     'review_taste': {'type': 'integer'},
#     'review_text': {'type': 'text'}}},
#   'settings': {'index': {'routing': {'allocation': {'include': {'_tier_preference': 'data_content'}}},
#     'refresh_interval': '-1',
#     'number_of_shards': '4',
#     'provided_name': 'beers',
#     'similarity': {'default': {'type': 'BM25', 'b': '0.825', 'k1': '1.2'}},
#     'max_result_window': '20000',
#     'creation_date': '1716649304831',
#     'analysis': {'analyzer': {'std_english': {'type': 'standard',
#        'stopwords': '_english_'}}},
#     'number_of_replicas': '0',
#     'uuid': 'PLz5g2xTToGU-5JNuX9VcA',
#     'version': {'created': '8500008'}}}}}

# %%
# bulk indexing (via official API)

#connect to the local elasticsearch node and authenticate
es = Elasticsearch([ES_ENDPOINT], ca_certs=path_to_ca_certificates, basic_auth=(USER, PWD))

actions = [
  {
    "_index": index_name,
    "_id": doc_id,
    "_source": doc
  }
  for doc_id, doc in list(zip(doc_ids, docs))
]

# Point #1: Taking care of efficient loading by bulk indexing
bulk(es, actions)
# Out:
# (582049, [])

# %%
# reset the refresh interval to 2 seconds as it is needed after indexing
r = e.curl('put', 'beers/_settings', {'index' : {'refresh_interval' : '2s'}})
r.json()
# Point #2 (not sure if this would make a rare update but it would make the data base static for sure)
# r = e.curl('put', 'beers/_settings', {'index' : {'refresh_interval' : '-1'}}) 
# r.json()
# Out:
# {'acknowledged': True}

# %%
# Checking
r = e.curl('get', f'beers/_doc/{doc_ids[42]}')
r.json()
# Out:
# {'_index': 'beers',
#  '_id': '42',
#  '_version': 1,
#  '_seq_no': 7,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'beer_name': 'Dogfish Head ApriHop',
#   'beer_style': 'Fruit Beer',
#   'beer_ABV': '7',
#   'review_appearance': 4,
#   'review_aroma': 9,
#   'review_palate': 4,
#   'review_taste': 8,
#   'review_overall': 16,
#   'review_profileName': 'Jan Primus',
#   'review_text': 'Pours a nice, clear copper colour with small white head. Was somewhat skeptical how the apricot and hops would mesh but this turned out just fine as they were both well balanced, and the fruity apricot made the beer very refreshing on a hot evening, adding a subtle touch of sweetness to an ipa. Looking forward to trying this again.'}}

# %%
# delete the index
# r = e.curl('delete', 'beers')
# r.json()

# %% [markdown]
# ### Querying

# %% [markdown]
# #### Point #6: Exact match query on the beer name

# %%
""" 
execute an exact-match query for the beer "Icehouse"
"""
r1 = e.curl('get', f'beers/_search',{
 "query": {
     "match_phrase": {
         "beer_name": {
             "query": "Icehouse"
}}}})

r1.json()
# Out:
# {'took': 101,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 179, 'relation': 'eq'},
#   'max_score': 12.337053,
#   'hits': [{'_index': 'beers',
#     '_id': '1',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 3,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': 'xav33',
#      'review_text': 'Icehouse\tDeuce-Deuce\tRecent browing, resided in 11/06\tMedium pour in a pint glass.\t\tPoured a slightly pale yellow with a fizzy mostly diminishing white head.\t\tSmelt of faint grain. \t\tTaste was upfront sweet drainage water with maybe hints of grain flavoring followed by an execrable harsh bitter fat mans bat tub water taste.  Mouthfeel was light bodied, watery-ish, fizzy and strongly astringent on the finish.\t\tOverall, I never actually tasted this beer until today.  Ive drank it a few times and thought it was ok, but never *tasted* it.  Dont taste it.  Just enjoy the buzz.'}},
#    {'_index': 'beers',
#     '_id': '326',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 2,
#      'review_aroma': 3,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 6,
#      'review_profileName': 'lithy',
#      'review_text': 'Pale yellow, ugly, thin white head.  Aroma is faint corn, taste is harsh bitter tannic malt, metal, not good.'}},
#    {'_index': 'beers',
#     '_id': '6476',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 1,
#      'review_aroma': 1,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': 'lndnkid',
#      'review_text': 'there is no suprise that 2 24oz cans cost $2.15 you cant get a better deal for 48oz of horse urine.  it inspired me too visit the local strip club and polish off a pitcher more!!!  at that point I thought I was Steve McQueen, in the end I totalled my 99 Mustang, I sure hope 34,000 dollars was worth the $2.15 that started this journey.\t\tDisclaimer:  My friends tale, not mine'}},
#    {'_index': 'beers',
#     '_id': '12757',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 2,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 8,
#      'review_profileName': 'brettpace',
#      'review_text': 'I remember kids drinking this shit in college thinking they were badasses drinking a beer at 5.5% (how lame).  Cheap taste, rotten beer, would NEVER buy again.'}},
#    {'_index': 'beers',
#     '_id': '29074',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 1,
#      'review_aroma': 2,
#      'review_palate': 2,
#      'review_taste': 3,
#      'review_overall': 5,
#      'review_profileName': 'SkyCop32',
#      'review_text': 'This is clear with a small white head and no aroma or taste to mention.  This is just the typical watery lager you have come to expect in the U.S.'}},
#    {'_index': 'beers',
#     '_id': '48785',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 2,
#      'review_aroma': 4,
#      'review_palate': 3,
#      'review_taste': 4,
#      'review_overall': 8,
#      'review_profileName': 'freezy',
#      'review_text': 'cheap mass produced beer...not deadly awful. Head disappears faster than an elephant at a David Copperfield show.  Pale yellow, smell weak dandelion and corn. taste corn, slightly floral, weak cider and tin. Med/high carbonation'}},
#    {'_index': 'beers',
#     '_id': '57895',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 3,
#      'review_aroma': 3,
#      'review_palate': 4,
#      'review_taste': 7,
#      'review_overall': 10,
#      'review_profileName': 'avalancher34',
#      'review_text': 'I love this beer, even though its not the greatest. It has a decent aroma, pretty good taste, plus is cheap. I can get a 12 pack for about 6.50 at the local grocery store. Wonderfully refreshing when served in a mug straight from the freezer. Not much flavor, but damn resfreshing'}},
#    {'_index': 'beers',
#     '_id': '66601',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 1,
#      'review_aroma': 1,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 2,
#      'review_profileName': 'ClarkVV',
#      'review_text': 'Wow how could I forget to rate this beer. It has a wonderful hop flavor, followed by an elegant complex malty full body that goes on forever, finish is clean and lingering complex fruit and malt flavors intermingle and dance on the palette as it leaves.  Just kidding. this beer tastes like poop.'}},
#    {'_index': 'beers',
#     '_id': '105960',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 4,
#      'review_aroma': 3,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 10,
#      'review_profileName': 'Phrozt99',
#      'review_text': 'Icehouse really isnt a bad beer, though it has a bit of a strong aftertaste.  A lot of people I know cant stand it, but I would prefer it over several normal party beers.'}},
#    {'_index': 'beers',
#     '_id': '115157',
#     '_score': 12.337053,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 2,
#      'review_aroma': 1,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': 'cb',
#      'review_text': 'I can\'t believe they included the phrase,"no watered-down taste". What a crock.'}}]}}

# %% [markdown]
# #### Point #7: Full-text query on beer name and review, with review boosted by a factor 1.7 compared to beer name

# %%
""" 
execute a full-text query for the query where overall review is 9
"""
query = {
"query": {
    "multi_match": {
            "query": "9",
            "fields": ["beer_name", "review_overall^1.7"],
            "type": "phrase"
}}}
r = e.curl('get', f'beers/_search', query)
r.json()
# Out:
# {'took': 32,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 8.61025,
#   'hits': [{'_index': 'beers',
#     '_id': '120435',
#     '_score': 8.61025,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 4,
#      'review_aroma': 8,
#      'review_palate': 4,
#      'review_taste': 8,
#      'review_overall': 16,
#      'review_profileName': 'CampbellWilson',
#      'review_text': 'Bottle from Beers of Europe. Hazy golden yellow with white persistant head. Spicy aroma with orangey hop. Pleasantly warming with an alcohol, spice and hop finish. Good stuff.'}},
#    {'_index': 'beers',
#     '_id': '177558',
#     '_score': 8.61025,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 5,
#      'review_aroma': 8,
#      'review_palate': 5,
#      'review_taste': 10,
#      'review_overall': 18,
#      'review_profileName': 'HazelRah',
#      'review_text': 'Massive snow white head.  Golden yellow with a slight vinegar/vinous nose.  Champagne flavour; coats the tonque exquisitely.  Dry and tingly, brimming with effervescence.'}},
#    {'_index': 'beers',
#     '_id': '303943',
#     '_score': 8.61025,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 3,
#      'review_aroma': 6,
#      'review_palate': 3,
#      'review_taste': 6,
#      'review_overall': 13,
#      'review_profileName': 'Jsawyer',
#      'review_text': 'Poured translucent gold with a thin white foamy head. Aroma was of light peach, apricot, candi sugar. Flavor was sweet banana, peach, apricot, phenolic, spicey yeast, cloves, cinnamon, and overall very sweet. Palate is too alcoholic, a friend mentioned it tasted like paint thinner. It wasnt that bad; nicely fruity and sweet but too highly attenuated.'}},
#    {'_index': 'beers',
#     '_id': '422816',
#     '_score': 8.61025,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 5,
#      'review_aroma': 6,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 12,
#      'review_profileName': 'stubby',
#      'review_text': 'Smelled like smoked sausage when I opened it.  If that hadnt happened I would have liked this a lot more.  Decent but hot compared to other Belgian strongs.'}},
#    {'_index': 'beers',
#     '_id': '425975',
#     '_score': 8.61025,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 3,
#      'review_aroma': 7,
#      'review_palate': 4,
#      'review_taste': 9,
#      'review_overall': 18,
#      'review_profileName': 'mjmeijer2',
#      'review_text': 'Golden brown appearance with lots of carbonation and a foamy head.  Taste is bitter at first then finishes sweet fruity and sweet with a lingering palate.  Good beer, more hoppy than most Belgians.'}},
#    {'_index': 'beers',
#     '_id': '530801',
#     '_score': 8.61025,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 3,
#      'review_aroma': 7,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 12,
#      'review_profileName': 'zeek',
#      'review_text': 'Pours a huge head that fades fast, but the last cm sticks around for a while.  Color is a nice gold with a reddish tinge to it.  \t\tThe alcohol doesnt come through too strongly for a 9%.  The beer is quite thick and finishes quite bitter all on the roof of the mouth.'}},
#    {'_index': 'beers',
#     '_id': '34698',
#     '_score': 8.501554,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 3,
#      'review_aroma': 5,
#      'review_palate': 3,
#      'review_taste': 6,
#      'review_overall': 12,
#      'review_profileName': 'MaartenRF10',
#      'review_text': 'Vrij sterk. Smaak een beetje caramel, verder weinig te ontdekken in de smaak. Veel koolzuur.'}},
#    {'_index': 'beers',
#     '_id': '68401',
#     '_score': 8.501554,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 3,
#      'review_aroma': 7,
#      'review_palate': 4,
#      'review_taste': 6,
#      'review_overall': 14,
#      'review_profileName': 'drfabulous',
#      'review_text': '10 percent? 9 percent? Its all pretty good when you are downtown at the only bar with a decent list and this is available. Why its not available in any of our stores is beyond me.....'}},
#    {'_index': 'beers',
#     '_id': '104412',
#     '_score': 8.501554,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 3,
#      'review_aroma': 6,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 10,
#      'review_profileName': 'jonwayne4883',
#      'review_text': 'citrus hops very evident in taste. small head that lingered, yellowish brown color. for 9% it really isnt evident.'}},
#    {'_index': 'beers',
#     '_id': '129050',
#     '_score': 8.501554,
#     '_source': {'beer_name': 'Piraat 9%',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '9',
#      'review_appearance': 4,
#      'review_aroma': 7,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 16,
#      'review_profileName': 'janubio',
#      'review_text': '330 ml. bottle. Golden colour, a thick non compact head that leaves lace and a ring on the surface when its gone. Fruity aroma, apples, oranges, maybe bananas and maybe pine too Some coriander.\tSilky champagne-like flavor, taste is sweet, some spices, clove, coriander, fruits, but not as distinctive as in the aroma.'}}]}}

# %% [markdown]
# #### Point #8: Full-text query on the review text, and that filters the results by category

# %%
""" 
execute a full-text query for the query "Icehouse" in the review text and filter the results by the beer style
"""
query = {
    "query": {
      "bool": {
       "must": {
         "match": {
                "review_text": "Icehouse"
        }},
        "filter": {
          "term": {
                "beer_style": "Pale Lager"
}}}}}
r = e.curl('get', f'beers/_search', query)
r.json()
# Out:
# {'took': 16,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 34, 'relation': 'eq'},
#   'max_score': 13.96607,
#   'hits': [{'_index': 'beers',
#     '_id': '161519',
#     '_score': 13.96607,
#     '_source': {'beer_name': 'Icehouse Light',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5',
#      'review_appearance': 1,
#      'review_aroma': 1,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': '666seth',
#      'review_text': 'Even worse than the regular Icehouse. Stay away! Your better off buying carbonated water (cheaper)'}},
#    {'_index': 'beers',
#     '_id': '359066',
#     '_score': 13.254322,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 1,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 3,
#      'review_profileName': 'psychodrama311',
#      'review_text': 'what happened to the good old american beer? the one that doesnt rip off their formula from europe. well for some reason they put water in it. like icehouse for example. i love the description of no watered-down taste. have the people actually tasted icehouse..lol.'}},
#    {'_index': 'beers',
#     '_id': '57802',
#     '_score': 13.1491995,
#     '_source': {'beer_name': 'Icehouse Light',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5',
#      'review_appearance': 2,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 3,
#      'review_overall': 3,
#      'review_profileName': 'Ringo',
#      'review_text': 'If regular Icehouse just does not fill your requirements for a crappy beer, you can always rely on this one.'}},
#    {'_index': 'beers',
#     '_id': '446940',
#     '_score': 12.99716,
#     '_source': {'beer_name': 'Icehouse Light',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5',
#      'review_appearance': 2,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 4,
#      'review_profileName': 'iamsancho16',
#      'review_text': 'I didnt really taste much of a difference between this and original Icehouse.  However, Id still prefer to drink Busch Ice.'}},
#    {'_index': 'beers',
#     '_id': '180881',
#     '_score': 12.9890585,
#     '_source': {'beer_name': 'Icehouse Light',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5',
#      'review_appearance': 2,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 4,
#      'review_profileName': 'jrallen34',
#      'review_text': 'Icehouse isnt bad enough, they had to make this? watery but with a ton of alcohol, not a fan'}},
#    {'_index': 'beers',
#     '_id': '435433',
#     '_score': 12.68911,
#     '_source': {'beer_name': 'Keystone Ice',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.9',
#      'review_appearance': 1,
#      'review_aroma': 1,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': 'sanmiguel',
#      'review_text': 'Ugh. Like Icehouse, it is a shitty, poor university beer. Very watery and unappetising; and a metallic finish. To the bins!'}},
#    {'_index': 'beers',
#     '_id': '429726',
#     '_score': 12.634861,
#     '_source': {'beer_name': 'Icehouse Light',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5',
#      'review_appearance': 1,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 5,
#      'review_profileName': 'JLAudio',
#      'review_text': 'Not bad...a little worse than Icehouse but if you are cheap and are counting calories....ok then give it a whirl'}},
#    {'_index': 'beers',
#     '_id': '413081',
#     '_score': 12.082134,
#     '_source': {'beer_name': 'Red Dog',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5',
#      'review_appearance': 2,
#      'review_aroma': 2,
#      'review_palate': 3,
#      'review_taste': 3,
#      'review_overall': 5,
#      'review_profileName': 'Bockyhorsey',
#      'review_text': 'King Can. Standard swill beer that is simular to Icehouse. Went down good while playing cards but wouldnt buy this as something to fill the fridge.'}},
#    {'_index': 'beers',
#     '_id': '105960',
#     '_score': 11.987446,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 4,
#      'review_aroma': 3,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 10,
#      'review_profileName': 'Phrozt99',
#      'review_text': 'Icehouse really isnt a bad beer, though it has a bit of a strong aftertaste.  A lot of people I know cant stand it, but I would prefer it over several normal party beers.'}},
#    {'_index': 'beers',
#     '_id': '240225',
#     '_score': 11.951426,
#     '_source': {'beer_name': 'Icehouse Light',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5',
#      'review_appearance': 2,
#      'review_aroma': 2,
#      'review_palate': 2,
#      'review_taste': 3,
#      'review_overall': 5,
#      'review_profileName': 'Shag',
#      'review_text': 'Why make a lite ice beer? If you wanna drink icehouse you must want to get drunk right? Why settle on less alcohol? Please stop this nonsense!'}}]}}

# %% [markdown]
# #### Point #9: Fuzzy query on the beer name

# %%
query ={
  "query": {
    "fuzzy": {
      "beer_name": {
        "value": "Icehouse",
        "fuzziness": "AUTO",
}}}}
r = e.curl('get', f'beers/_search', query)
r.json()
# Out:
# {'took': 41,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 261, 'relation': 'eq'},
#   'max_score': 10.794922,
#   'hits': [{'_index': 'beers',
#     '_id': '1',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 3,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': 'xav33',
#      'review_text': 'Icehouse\tDeuce-Deuce\tRecent browing, resided in 11/06\tMedium pour in a pint glass.\t\tPoured a slightly pale yellow with a fizzy mostly diminishing white head.\t\tSmelt of faint grain. \t\tTaste was upfront sweet drainage water with maybe hints of grain flavoring followed by an execrable harsh bitter fat mans bat tub water taste.  Mouthfeel was light bodied, watery-ish, fizzy and strongly astringent on the finish.\t\tOverall, I never actually tasted this beer until today.  Ive drank it a few times and thought it was ok, but never *tasted* it.  Dont taste it.  Just enjoy the buzz.'}},
#    {'_index': 'beers',
#     '_id': '326',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 2,
#      'review_aroma': 3,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 6,
#      'review_profileName': 'lithy',
#      'review_text': 'Pale yellow, ugly, thin white head.  Aroma is faint corn, taste is harsh bitter tannic malt, metal, not good.'}},
#    {'_index': 'beers',
#     '_id': '6476',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 1,
#      'review_aroma': 1,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': 'lndnkid',
#      'review_text': 'there is no suprise that 2 24oz cans cost $2.15 you cant get a better deal for 48oz of horse urine.  it inspired me too visit the local strip club and polish off a pitcher more!!!  at that point I thought I was Steve McQueen, in the end I totalled my 99 Mustang, I sure hope 34,000 dollars was worth the $2.15 that started this journey.\t\tDisclaimer:  My friends tale, not mine'}},
#    {'_index': 'beers',
#     '_id': '12757',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 2,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 8,
#      'review_profileName': 'brettpace',
#      'review_text': 'I remember kids drinking this shit in college thinking they were badasses drinking a beer at 5.5% (how lame).  Cheap taste, rotten beer, would NEVER buy again.'}},
#    {'_index': 'beers',
#     '_id': '29074',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 1,
#      'review_aroma': 2,
#      'review_palate': 2,
#      'review_taste': 3,
#      'review_overall': 5,
#      'review_profileName': 'SkyCop32',
#      'review_text': 'This is clear with a small white head and no aroma or taste to mention.  This is just the typical watery lager you have come to expect in the U.S.'}},
#    {'_index': 'beers',
#     '_id': '48785',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 2,
#      'review_aroma': 4,
#      'review_palate': 3,
#      'review_taste': 4,
#      'review_overall': 8,
#      'review_profileName': 'freezy',
#      'review_text': 'cheap mass produced beer...not deadly awful. Head disappears faster than an elephant at a David Copperfield show.  Pale yellow, smell weak dandelion and corn. taste corn, slightly floral, weak cider and tin. Med/high carbonation'}},
#    {'_index': 'beers',
#     '_id': '57895',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 3,
#      'review_aroma': 3,
#      'review_palate': 4,
#      'review_taste': 7,
#      'review_overall': 10,
#      'review_profileName': 'avalancher34',
#      'review_text': 'I love this beer, even though its not the greatest. It has a decent aroma, pretty good taste, plus is cheap. I can get a 12 pack for about 6.50 at the local grocery store. Wonderfully refreshing when served in a mug straight from the freezer. Not much flavor, but damn resfreshing'}},
#    {'_index': 'beers',
#     '_id': '66601',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 1,
#      'review_aroma': 1,
#      'review_palate': 1,
#      'review_taste': 2,
#      'review_overall': 2,
#      'review_profileName': 'ClarkVV',
#      'review_text': 'Wow how could I forget to rate this beer. It has a wonderful hop flavor, followed by an elegant complex malty full body that goes on forever, finish is clean and lingering complex fruit and malt flavors intermingle and dance on the palette as it leaves.  Just kidding. this beer tastes like poop.'}},
#    {'_index': 'beers',
#     '_id': '105960',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 4,
#      'review_aroma': 3,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 10,
#      'review_profileName': 'Phrozt99',
#      'review_text': 'Icehouse really isnt a bad beer, though it has a bit of a strong aftertaste.  A lot of people I know cant stand it, but I would prefer it over several normal party beers.'}},
#    {'_index': 'beers',
#     '_id': '115157',
#     '_score': 10.794922,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 2,
#      'review_aroma': 1,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': 'cb',
#      'review_text': 'I can\'t believe they included the phrase,"no watered-down taste". What a crock.'}}]}}

# %% [markdown]
# #### Point #10: Full-text query on the review text, with results sorted by decreasing rating on the beer aroma (highest to lowest)

# %%
""" 
execute a full-text query for the query "enjoy" in the review text and sorting the results
"""
query = {
    "query": {
      "match": {
            "review_text": "enjoy" 
    }},
    "sort": [{
      "review_aroma": {
            "order": "desc" 
}}]}

r = e.curl('get', f'beers/_search', query)
r.json()
# Out:
# {'took': 43,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 5497, 'relation': 'eq'},
#   'max_score': None,
#   'hits': [{'_index': 'beers',
#     '_id': '11540',
#     '_score': None,
#     '_source': {'beer_name': 'Presidente',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5',
#      'review_appearance': 5,
#      'review_aroma': 10,
#      'review_palate': 5,
#      'review_taste': 10,
#      'review_overall': 20,
#      'review_profileName': 'rosilet',
#      'review_text': 'ligth and flavory, low alcohol volume, its perfect when drunk chilled, maybe thats why some raters did not enjoy it...'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '53621',
#     '_score': None,
#     '_source': {'beer_name': 'Founders KBS (Kentucky Breakfast Stout)',
#      'beer_style': 'Imperial Stout',
#      'beer_ABV': '11.2',
#      'review_appearance': 4,
#      'review_aroma': 10,
#      'review_palate': 5,
#      'review_taste': 10,
#      'review_overall': 20,
#      'review_profileName': 'andyhwcinc',
#      'review_text': 'Enjoyed 4 oz sampler glass at Founders tasting event at Binnys South Loop in Chicago, IL.  Luckily this event was held as every bottle in the Chicagoland area sold out quickly and this was my only shot at having this...and Im glad I got to.  Appearance pure black with a thin off white head.  Aroma equal parts bourbon, chocolate, lactose, coffee, toffee, smells extremely smooth, flat out impressive.  Taste decadently smooth, very creamy, I dont even want to know the ABV of this one (later found out it was 11.2%...ouch!).  The bourbon serves as a complimentary ingredient, doesnt dominate the palate and enhances the chocolate notes.  Would drink and enjoy this often if I could, a definite 1%er of all the beers Ive ever had.'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '79142',
#     '_score': None,
#     '_source': {'beer_name': 'Saint Arnold Elissa IPA',
#      'beer_style': 'India Pale Ale (IPA)',
#      'beer_ABV': '6.6',
#      'review_appearance': 4,
#      'review_aroma': 10,
#      'review_palate': 5,
#      'review_taste': 10,
#      'review_overall': 20,
#      'review_profileName': 'jezmez68',
#      'review_text': 'Sampled at the Flying Saucer in Houston.  I sampled this right after the Dogfish Head IPA and both were equally fantastic beers.  Although I enjoy IPAs, normally they are too hoppy for me to enjoy.  This beer started hoppy but finished with a smooth mouthfeel.  Worth the trip to Texas.'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '108578',
#     '_score': None,
#     '_source': {'beer_name': 'Nils Oscar Jull 2001 & 2002',
#      'beer_style': 'Scotch Ale',
#      'beer_ABV': '7',
#      'review_appearance': 5,
#      'review_aroma': 10,
#      'review_palate': 4,
#      'review_taste': 9,
#      'review_overall': 19,
#      'review_profileName': 'Ingevara',
#      'review_text': 'Wonderful fullbodied winter warmerm saturated with nuances that make you just want to sit down and enjoy. And enjoy again\tand again...'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '125306',
#     '_score': None,
#     '_source': {'beer_name': 'Rogue Chocolate Stout',
#      'beer_style': 'Sweet Stout',
#      'beer_ABV': '6.3',
#      'review_appearance': 3,
#      'review_aroma': 10,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 14,
#      'review_profileName': 'jmohno',
#      'review_text': 'Not big on stouts, but enjoy them ocassionally.A typical good stout, very good milk chocolate aroma,smooth mouthfeel chocolate and coffee roast taste balanced by a good amout of hop bittering that lingers with the dry roast, the aroma is the best feature for me its the best stout chocolate aroma  i have tried.Coffee like bitterness lingers. Kind of thin in the finish.Not my favorite stout but definatlely one of the better ones,glad i tried it wont get it anytime too soon.'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '140199',
#     '_score': None,
#     '_source': {'beer_name': 'Founders Harvest Ale',
#      'beer_style': 'India Pale Ale (IPA)',
#      'beer_ABV': '6.5',
#      'review_appearance': 3,
#      'review_aroma': 10,
#      'review_palate': 4,
#      'review_taste': 10,
#      'review_overall': 19,
#      'review_profileName': 'ilherps',
#      'review_text': 'This beer pours a clear yellowish with a fizzy white foam.  The aroma is intense.  Citrus, creamsicle, pine, citrus, mango, citrus, and a little bit of locker room sneak through.  Intensely citrus and fresh, fresh hops, which is where that locker room hint comes from, very thick and resiny.  The flavor is quite hoppy, focused on citrus.  I really enjoy this beer, a lot.  If you like nothing but hops, you will too.'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '155520',
#     '_score': None,
#     '_source': {'beer_name': 'Russian River Pliny the Younger',
#      'beer_style': 'Imperial/Double IPA',
#      'beer_ABV': '11',
#      'review_appearance': 5,
#      'review_aroma': 10,
#      'review_palate': 5,
#      'review_taste': 10,
#      'review_overall': 20,
#      'review_profileName': 'antioch',
#      'review_text': 'I acquired a growler of the infamous Younger from vacax (thanks mate)! Served it in a Bruery tulip glass. I poured 3 glasses of RR brews and compared them. Blind Pig, Pliny the Elder and Pliny the Younger.\t\tA - A beautiful orange/copper tone with minimal head but amazing lacing that lasted the whole glass. A darker orange color than that of its uncle.\t\tS - Chocked full of piney aroma! Compared with the Elder it was far more hop aroma, grapefruit, citrus and pine just fills your nose! Absolutely beautiful smell!\t\tT - Grapefruit, pine and citrus; just as the scent would allude to! Bitter! But, not over the top (believe it or not). It was a well balanced bitterness, no funny facial expressions after taking a sip of this beer. Insanely flavorful and potent! Some beers youll need a few sips to get the flavor, this one is not that! If youre offered a sip of the Younger, take it and youll know how it tastes! No new flavors come through near the end!\t\tM - Medium bodied, nice carbonation that creates a little dance party on your tongue. The finish sticks around too, which I really enjoy in good beers. Its a shame when they go away quickly, the Younger does not do this!\t\tD - 2 friends came over and we had the growler gone in less than an hour! 11% so be careful! This is no harder to drink than Blind Pig or Pliny the Elder! Amazing for such a big beer!\t\tI would say I was blessed to have been able to finally get this beer. I would love to get some every year! For anybody thats wondering if they should try to pile into a small bar to try get this on tap, I would say DO IT!'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '159869',
#     '_score': None,
#     '_source': {'beer_name': 'Founders Reds Rye P.A.',
#      'beer_style': 'Specialty Grain',
#      'beer_ABV': '6.6',
#      'review_appearance': 5,
#      'review_aroma': 10,
#      'review_palate': 5,
#      'review_taste': 8,
#      'review_overall': 18,
#      'review_profileName': 'MagooinPA',
#      'review_text': 'Draft at Theresas in Wayne,Pa. Nice red/dark copper color with a rocky 2 finger head. Well poured as everything here is including the 2 cask beers(not easy if youve never done it). Like Monks, these girls know their beer. My young waitress said she loved this beer and wondered why it took so long to get it.This beer looks great and the nose is even better. I smelled a perfect hop aroma that I have not experienced since I had Victory Hop Devil on cask for the 1st time. This was perfect. All that flowering hop aroma with an awesome appearance.The 1st taste was better than I expected since my anticipation from my sense of smell and sight of this marvel was most likely yet another disappointment. This surpassed in taste what I thought was going to be a great beer. It was the best beer I ever had. Wow! I have no perfect scores here in my little file of reviews, but then again, the day I taste the perfect beer, what is the point of going on? Pursuit is the best part of the game. My favorite beer before this was Youngs SLA and I considered that the perfect harmony of all things beer. F**K styles and guidelines, it is what tastes good to you. I have a new perfectly harmonic new favorite. By the way, the abv (6.8)is not even remotely present in any way. Enjoy this folks, it is a gem.'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '160033',
#     '_score': None,
#     '_source': {'beer_name': 'Dogfish Head 60 Minute IPA',
#      'beer_style': 'India Pale Ale (IPA)',
#      'beer_ABV': '6',
#      'review_appearance': 5,
#      'review_aroma': 10,
#      'review_palate': 5,
#      'review_taste': 9,
#      'review_overall': 19,
#      'review_profileName': 'scottmc',
#      'review_text': 'This is a true American IPA. A great balance of hops that bitter and add a fruity aroma to the taste. I feel right at home with this beer. The hoppy aroma and taste leave your mouth wanting another sip. Easy to drink and enjoy.'},
#     'sort': [10]},
#    {'_index': 'beers',
#     '_id': '169545',
#     '_score': None,
#     '_source': {'beer_name': 'De Dolle Stille Nacht Reserva 2000',
#      'beer_style': 'Belgian Strong Ale',
#      'beer_ABV': '12',
#      'review_appearance': 4,
#      'review_aroma': 10,
#      'review_palate': 5,
#      'review_taste': 9,
#      'review_overall': 19,
#      'review_profileName': 'deadfryday',
#      'review_text': 'This is one of the 5 best beers in the world hands down.  Went to Brugge on Feb 11 2005 and bought 4 bottles to enjoy.  Great Aroma, excellent Flavor, and overall beautiful Ale.  Brent Smith July 2005'},
#     'sort': [10]}]}}
